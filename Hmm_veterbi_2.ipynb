# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from collections import defaultdict
import os
import xml.etree.ElementTree as et
import pandas as pd

# %% [markdown]
# Pre Processing

# %%
path='/content/drive/My Drive/Ai_project_hmm/Train-corpus'
transition_matrix = defaultdict(dict)
probability_matrix = defaultdict(dict)
initial_matrix = defaultdict(dict)
different_tags = []
different_words = {}
new_word = "#un#"
cardinal_word = "#un1#"

# %%
co_trans = defaultdict(dict)
co_tag_word = defaultdict(dict)
co_initial = defaultdict(dict)
p=[.85,.15]

for _dir,subdir,files in os.walk(path):
    for file in files:
            file_path=os.path.join(_dir,file)
            tree=et.parse(file_path)
            root=tree.getroot()
            prev = []
            prev_word='.'
            for word in root.findall('.//'):
                if word.tag=='w' or word.tag=='c' and w!=None:
                    w=word.text
                    tag=word.attrib.get('c5')
                    w=w.lower()
                    w=w.replace(' ','')
                    if w not in different_words:
                        different_words[w] = 1
                    taglist = tag.split('-')
                    if len(taglist)==1 :
                        taglist.append(taglist[0])

                    for i in taglist:
                        if i not in different_tags:
                            different_tags.append(i)
                    
                    co = 0;

                    for j in taglist:
                        if w not in co_tag_word[j] :
                            co_tag_word[j][w]=0
                        co_tag_word[j][w] += p[co]
                        if prev_word == '.':
                            if co_initial[j]=={}:
                                co_initial[j]=0
                            co_initial[j]+=p[co]
                        co+=1
                    if prev!=[]:
                        for i in range(0,2):
                            for j in range(0,2):
                                if taglist[j] not in co_trans[prev[i]]: 
                                    co_trans[prev[i]][taglist[j]]=0
                                co_trans[prev[i]][taglist[j]]+=p[i]*p[j]
                    if w.isdecimal():
                        cardinal_word = w
                    prev = taglist


load = {}
for i in different_tags:
    x = .1
    if i=='NP0' :
        x=.9
    load[i] = x;

for tag in co_tag_word:
    min_key = max(co_tag_word[tag],key = co_tag_word[tag].get)
    co_tag_word[tag][new_word]=load[tag]*co_tag_word[tag][min_key]

load2 = .01;

co_initial_sum = sum(co_initial.values())
for tag in co_initial:
    initial_matrix[tag] = co_initial[tag]/co_initial_sum

for i in co_trans:
    min_key = min(co_trans[i], key = co_trans[i].get)
    for j in different_tags:
        if j not in co_trans[i]:
            co_trans[i][j] = load2*co_trans[i][min_key] 

for i in co_trans:
    co_trans_sum = 0;
    co_trans_sum += sum(co_trans[i].values())
    for j in co_trans[i]:
        if j not in transition_matrix[i]:
             transition_matrix[i][j]=0
        transition_matrix[i][j] += co_trans[i][j]/co_trans_sum

for tag in co_tag_word:
    local_sum = sum(co_tag_word[tag].values())
    for x in co_tag_word[tag]:
        if x not in probability_matrix[tag]:
             probability_matrix[tag][x]=0
        probability_matrix[tag][x] += co_tag_word[tag][x]/local_sum

for tag in different_tags:
    if tag not in initial_matrix:
        initial_matrix[tag]=0

# %% [markdown]
# Veterbi Algorithm

# %%
test_path = '/content/drive/MyDrive/Ai_project_hmm/Test-corpus'

# %%
count = 0;
delta_matrix = {}
back_pointer = defaultdict(dict)
ma_list = []
t = 0
correct_assigned = 0
incorrect_assigned = 0
new_correct_assigned = 0;
new_incorrect_assigned = 0;
for _dir,subdir,files in os.walk(test_path):
    for file in files:
        file_path=os.path.join(_dir,file)
        tree=et.parse(file_path)
        root=tree.getroot()
        x1=0
        x2=0
        for word in root.findall('.//'):
            if (word.tag=='w' or word.tag=='c') and word.text != None:
                w=word.text
                tag=word.attrib.get('c5')
                w=w.lower()
                w=w.replace(' ','')
                if w.isdecimal():
                    w=cardinal_word
                taglist = tag.split('-')
                if w not in different_words:
                    w=new_word
                if len(delta_matrix) == 0:
                    for tag in different_tags:
                        y = 0
                        if w in probability_matrix[tag]:
                            y = probability_matrix[tag][w]
                        delta_matrix[tag]=initial_matrix[tag]*y
                else:
                    new_delta_matrix = {}
                    for tag in different_tags:
                        x = 0
                        back = "NP0"
                        for prev in different_tags:
                            z1 = delta_matrix[prev]
                            z2 = transition_matrix[prev][tag]
                            if x<(z1*z2) :
                                x = max(x, z1*z2)
                                back = prev
                        y = 0
                        if w in probability_matrix[tag]:
                            y=probability_matrix[tag][w]
                        x *= y
                        new_delta_matrix[tag] = x
                        back_pointer[t][tag]=back;
                    delta_matrix=new_delta_matrix
                    t+=1

                count+=1
                del_sum=sum(delta_matrix.values())
                # debug

                #debug
                for i in delta_matrix:
                    delta_matrix[i]/=del_sum
                ma_list.append(taglist)
                if w=='.':
                    assigned_tag = max(delta_matrix, key = delta_matrix.get)
                    assigned_lis = [assigned_tag]
                    cur_tag=assigned_tag
                    while t!=0:
                        t-=1
                        assigned_lis.append(back_pointer[t][cur_tag])
                        cur_tag=assigned_lis[-1]
                    assigned_lis.reverse()
                    ma = len(assigned_lis)
                    for i in range(0,ma):
                        if assigned_lis[i] in ma_list[i]:
                            correct_assigned+=1;
                            x1+=1;
                            # if w == new_word || w == cardinal_word:
                            #     new_correct_assigned+=1;
                        else: 
                            incorrect_assigned+=1
                            x2+=1;
                            # if w == new_word || w == cardinal_word:
                            #     new_incorrect_assigned+=1;
                    t=0;
                    back_pointer = defaultdict(dict)
                    ma_list = []
                    delta_matrix = {}
        local_acc = x1/(x1+x2)
        print("Local Accuracy of "+ file + " " + str(local_acc) )
print("Total accuracy: ")
print(correct_assigned/(incorrect_assigned+correct_assigned))
# Out:
# Local Accuracy of AYJ.xml 0.9734459387906386
# Local Accuracy of AYK.xml 0.97083392326207
# Local Accuracy of AYR.xml 0.9683481701285855
# Local Accuracy of AYX.xml 0.9637052232917784
# Local Accuracy of AYP.xml 0.9697042682402326
# Local Accuracy of AYM.xml 0.9558162864744624
# Local Accuracy of ATA.xml 0.9716383707463716
# Local Accuracy of AT7.xml 0.9659394525908316
# Local Accuracy of AT4.xml 0.9546846077174996
# Local Accuracy of AT3.xml 0.9728755479406332
# Local Accuracy of AT1.xml 0.9647083246834129
# Local Accuracy of AT6.xml 0.9648563128955285
# Local Accuracy of ATE.xml 0.9632806496500447
# Local Accuracy of AT8.xml 0.9720447499663027
# Local Accuracy of AT9.xml 0.9742448759439051
# Local Accuracy of ATG.xml 0.9815738314597244
# Local Accuracy of AS5.xml 0.9732843757913395
# Local Accuracy of ASJ.xml 0.9713557189217829
# Local Accuracy of ASL.xml 0.9697588757854335
# Local Accuracy of ASD.xml 0.9556547161101708
# Local Accuracy of AS1.xml 0.973780170168432
# Local Accuracy of AS0.xml 0.9742373675273728
# Local Accuracy of AS7.xml 0.9605627359030081
# Local Accuracy of ASN.xml 0.9725605583686876
# Local Accuracy of ASB.xml 0.9800983761756776
# Local Accuracy of ASW.xml 0.9680264608599779
# Local Accuracy of ASA.xml 0.9651772103658537
# Local Accuracy of ASC.xml 0.9679501959880101
# Local Accuracy of ASH.xml 0.9645373774509803
# Local Accuracy of AS3.xml 0.9612275202111863
# Local Accuracy of ASY.xml 0.9764299111884477
# Local Accuracy of ASV.xml 0.9590340059790733
# Local Accuracy of ASR.xml 0.9589288129480186
# Local Accuracy of ASF.xml 0.9666033808358304
# Local Accuracy of AS6.xml 0.9786233682796484
# Local Accuracy of AS4.xml 0.9599570766971648
# Local Accuracy of ASE.xml 0.9696005381351547
# Local Accuracy of ASS.xml 0.9697745149449397
# Local Accuracy of ASU.xml 0.963540441547095
# Local Accuracy of ASK.xml 0.9755840832163791
# Local Accuracy of AR2.xml 0.9653324306789653
# Local Accuracy of ARG.xml 0.9745835872435507
# Local Accuracy of ARA.xml 0.9641176470588235
# Local Accuracy of AR7.xml 0.9607641112750968
# Local Accuracy of AR0.xml 0.9691941055577419
# Local Accuracy of ARE.xml 0.9570032259617699
# Local Accuracy of ART.xml 0.9728548872017823
# Local Accuracy of ARC.xml 0.9809886885204785
# Local Accuracy of AR8.xml 0.9717375522567402
# Local Accuracy of ARP.xml 0.9538481624126901
# Local Accuracy of ARR.xml 0.9636194525644433
# Local Accuracy of ARW.xml 0.9672140303842717
# Local Accuracy of ARD.xml 0.9717298234440789
# Local Accuracy of ARM.xml 0.9463140321588612
# Local Accuracy of AR4.xml 0.9610806187183691
# Local Accuracy of AR5.xml 0.9541716050712926
# Local Accuracy of ARF.xml 0.966671542812561
# Local Accuracy of AR3.xml 0.9708942253555605
# Local Accuracy of ARJ.xml 0.9660206236799602
# Local Accuracy of ARK.xml 0.9715369443180094
# Local Accuracy of ARH.xml 0.9612907234430338
# Local Accuracy of ARS.xml 0.9687114500392509
# Local Accuracy of AR9.xml 0.9757473722528097
# Local Accuracy of ARB.xml 0.9682066788207568
# Local Accuracy of ARY.xml 0.9698213423466924
# Local Accuracy of ARX.xml 0.974752955960473
# Local Accuracy of APW.xml 0.9621568248653057
# Local Accuracy of APV.xml 0.967328003158622
# Local Accuracy of APK.xml 0.963406310705098
# Local Accuracy of APH.xml 0.9606386019354048
# Local Accuracy of AP0.xml 0.972723992784125
# Local Accuracy of AP8.xml 0.9685709978896593
# Local Accuracy of AP7.xml 0.9700388736133497
# Local Accuracy of APR.xml 0.9664901276450345
# Local Accuracy of APS.xml 0.9594049741108565
# Local Accuracy of APJ.xml 0.9753182644842816
# Local Accuracy of AP1.xml 0.9393263611196555
# Local Accuracy of APE.xml 0.9802891257154135
# Local Accuracy of APU.xml 0.9736872211417458
# Local Accuracy of APM.xml 0.9594600358270068
# Local Accuracy of APX.xml 0.9704872389791184
# Local Accuracy of APT.xml 0.9434880061042491
# Local Accuracy of APP.xml 0.9695040214477212
# Local Accuracy of APC.xml 0.9595806583471591
# Local Accuracy of APD.xml 0.966822442677161
# Local Accuracy of AP5.xml 0.9727587124235169
# Local Accuracy of APL.xml 0.9663121943646666
# Local Accuracy of APN.xml 0.9721988397224434
# Local Accuracy of AP6.xml 0.9716981132075472
# Local Accuracy of AN2.xml 0.9562737642585551
# Local Accuracy of ANF.xml 0.9646867848209059
# Local Accuracy of AN0.xml 0.9710287940893679
# Local Accuracy of ANM.xml 0.962658626288062
# Local Accuracy of ANL.xml 0.9709484029484029
# Local Accuracy of ANR.xml 0.9698500767323811
# Local Accuracy of AN3.xml 0.9736561215452048
# Local Accuracy of AN7.xml 0.9692192192192193
# Local Accuracy of ANA.xml 0.9771732150154708
# Local Accuracy of ANH.xml 0.9751198416006669
# Local Accuracy of AN8.xml 0.9700377231552897
# Local Accuracy of AN1.xml 0.9412036769381974
# Local Accuracy of ANC.xml 0.9577145792472215
# Local Accuracy of ANP.xml 0.9694605252118467
# Local Accuracy of ANS.xml 0.9712990454298758
# Local Accuracy of ANX.xml 0.9673779373151195
# Local Accuracy of AN4.xml 0.9616386265957276
# Local Accuracy of AND.xml 0.9762335176520629
# Local Accuracy of AN9.xml 0.9760604325419548
# Local Accuracy of ANJ.xml 0.9572591587516961
# Local Accuracy of ANK.xml 0.966067716067716
# Local Accuracy of ANU.xml 0.9701441396166937
# Local Accuracy of ANT.xml 0.9767754808473121
# Local Accuracy of ANY.xml 0.9745610750950757
# Local Accuracy of AN5.xml 0.9802839873356999
# Local Accuracy of ANB.xml 0.9585009771238073
# Total accuracy:
# 0.9675300963839785
